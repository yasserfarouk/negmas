# %%
import jgraph as jg
jg.Graph()
jg.Graph([(0,1), (0,2), (2,3), (3,4), (4,2), (2,5), (5,0), (6,3), (5,6)])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-9a3acb23a717> in <module>
#       1 import jgraph as jg
# ----> 2 jg.Graph([(0,1), (0,2), (2,3), (3,4), (4,2), (2,5), (5,0), (6,3), (5,6)])
#
# AttributeError: module 'jgraph' has no attribute 'Graph'
